# %%
import cv2
from IPython.display import Image

Image(filename='photoshop.png')

# %%
import numpy as np
from matplotlib import pyplot as plt

plt.hist(img.ravel(),256,[0,256])

plt.show()

# %%
# !export PATH=/Library/TeX/texbin:$PATH

# %%
import os
print(os.environ['PATH'])
# Out:
# /anaconda3/bin:/Library/Frameworks/Python.framework/Versions/3.7/bin:/usr/bin:/bin:/usr/sbin:/sbin:/usr/local/bin
